# %%
##importing dataset

import pandas as pd
as24 = pd.read_csv(r"C:\Users\kumar\OneDrive\Desktop\AS24\AS24 Data Analyst Case Study 2021 04\AS24 Data Analyst Case Study data 2021 04.csv")

# %%
##importing potentionally relevant libraries
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from matplotlib import rcParams
from matplotlib import pyplot as plt

sns.set()
rcParams['figure.figsize'] = 20, 20

# %%
##Loading the dataset as a dataframe
as24
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 0       350625839        Basic     Mitsubishi  16750                5
# 1       354412280        Basic  Mercedes-Benz  35950                4
# 2       349572992        Basic  Mercedes-Benz  11950                3
# 3       350266763        Basic           Ford   1750                6
# 4       355688985        Basic  Mercedes-Benz  26500                3
# ...           ...          ...            ...    ...              ...
# 78316   348704581        Basic          Lexus  15740                8
# 78317   359231940        Basic        Hyundai   2950                6
# 78318   362425932        Basic     Volkswagen   7850                8
# 78319   357164227        Basic         Toyota  13945                5
# 78320   353639932        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# ...

# %%
as24.head(20)
# Out:
#     article_id product_tier      make_name  price  first_zip_digit  \
# 0    350625839        Basic     Mitsubishi  16750                5
# 1    354412280        Basic  Mercedes-Benz  35950                4
# 2    349572992        Basic  Mercedes-Benz  11950                3
# 3    350266763        Basic           Ford   1750                6
# 4    355688985        Basic  Mercedes-Benz  26500                3
# 5    361204569        Basic     Volkswagen  24890                6
# 6    362784907        Basic           Fiat   2850                7
# 7    363942101        Basic        Renault  23740                2
# 8    358875204        Basic        Renault   7850                6
# 9    357547566        Basic          Mazda  13950                3
# 10   354745488        Basic        Peugeot  12425                2
# 11   351143394        Basic           Fiat   6500                7
# 12   355653285        Basic           Opel   6450                4
# ...

# %%
as24.tail(20)
# Out:
#        article_id product_tier   make_name  price  first_zip_digit  \
# 78301   358532382        Basic     Peugeot  11800                1
# 78302   357140328        Basic         Kia  16950                4
# 78303   357137167        Basic         BMW  10850                6
# 78304   364685189        Basic  Land Rover   7990                3
# 78305   348757058        Basic         BMW  54750                3
# 78306   360448434        Basic         BMW   7950                7
# 78307   359753393        Basic       Skoda  14950                3
# 78308   361201389        Basic     Renault   1250                7
# 78309   363212449        Basic     Renault  15940                6
# 78310   355474323        Basic       Iveco  27850                6
# 78311   350268168        Basic        Opel   1299                3
# 78312   353639867        Basic    Daihatsu   2749                3
# 78313   353637877        Basic     Renault   6950                5
# ...

# %% [markdown]
# The following steps explain data cleaning and general analysis. The total no of records in the dataset initially is 78321 rows with 12 columns. Let's check duplicates in our dataset and the number of unique article_id. There might be some code cells that might seem unnecessary, but this is just a playground analysis with data and then further cleaning.

# %%
as24.article_id.unique()
# Out:
# array([350625839, 354412280, 349572992, ..., 362425932, 357164227,
#        353639932], dtype=int64)

# %%
list(set(as24.article_id))
# Out:
# [348782592,
#  358875137,
#  360448001,
#  360448003,
#  360448004,
#  360448006,
#  358875142,
#  358875144,
#  358875145,
#  360448010,
#  360448008,
#  360448012,
#  360448011,
#  360448014,
#  360448015,
#  360814353,
#  363200529,
#  358875154,
#  358875155,
#  348782612,
#  360448021,
#  358875158,
#  348782613,
#  360448023,
#  358875160,
#  360448026,
#  360448027,
#  360448028,
#  363593757,
#  358875166,
#  363593759,
#  360448032,
#  363593761,
#  358875167,
#  358875171,
#  363593764,
#  360448036,
#  360084912,
#  360084913,
#  363593768,
#  360448038,
#  358875178,
#  363593770,
#  361496620,
#  358875182,
#  360448047,
#  361496622,
#  363593778,
#  363593779,
#  358875188,
#  363593780,
#  360448053,
#  360448054,
#  348782642,
#  360448051,
#  363593784,
#  358875195,
#  354418748,
#  363593788,
#  363593790,
#  363593791,
#  358875200,
#  357115039,
#  358875202,
#  358875203,
#  358875204,
#  361496645,
#  361496644,
#  358875207,
#  358875206,
#  358875209,
# ...

# %%
## Number of unique articles
numberofarticles = as24["article_id"].value_counts()
print(numberofarticles)
# Out:
# 350214315    2
# 354755822    2
# 360793587    2
# 360768632    2
# 360768627    2
#             ..
# 361529437    1
# 359772580    1
# 357868406    1
# 350213731    1
# 353639932    1
# Name: article_id, Length: 78305, dtype: int64

# %%
as24['article_id'].nunique()
# Out:
# 78305

# %%
as24['article_id'].count()
# Out:
# 78321

# %%
as24.article_id.duplicated().sum()
# Out:
# 16

# %% [markdown]
# The total no articles initally was 78321 with 16 duplicate articles. However 16 duplicate articles may or maynot have the same other columns. i.e. An article might be listed initally as under a product_tier = 'Basic' and the same article can be listed later under a different product_tier,. e.g. 'Plus' and 'Premium'.

# %%
##article_id of duplicates
numberofarticles.head(16)
# Out:
# 350214315    2
# 354755822    2
# 360793587    2
# 360768632    2
# 360768627    2
# 350214314    2
# 360768625    2
# 357528924    2
# 360768624    2
# 360768628    2
# 364638423    2
# 354755829    2
# 354755824    2
# 359772384    2
# 360472733    2
# 358519054    2
# Name: article_id, dtype: int64

# %% [markdown]
# Let's check out the columns of the duplicated article_id. What are the possibilities of their columns to be same or different, or it's just a basic duplicate with all the columns being same.

# %%
as24.loc[as24.article_id.duplicated(), :]
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 33971   354755829         Plus           Ford  10950                7
# 36742   360768632      Premium          Honda   1990                8
# 37599   360768624      Premium        Hyundai   2990                8
# 44079   364638423      Premium           SEAT   5985                6
# 50392   350214314      Premium           Opel   8250                5
# 51125   357528924        Basic           SEAT  28490                7
# 53974   359772384        Basic          Skoda   5950                7
# 54721   360768625      Premium            BMW   2745                8
# 56967   360472733      Premium          Volvo   2990                5
# 62715   360793587        Basic        Renault   6450                8
# 63500   350214315        Basic         Nissan  13650                5
# 66323   354755822        Basic  Mercedes-Benz   6950                7
# ...

# %% [markdown]
# Let's check what columns or subsets do these duplicated id's have in common.

# %%
as24.loc[as24.duplicated(subset = ['article_id', 'make_name', 'price', 'first_zip_digit', 'created_date', 'first_registration_year'])]
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 33971   354755829         Plus           Ford  10950                7
# 36742   360768632      Premium          Honda   1990                8
# 37599   360768624      Premium        Hyundai   2990                8
# 44079   364638423      Premium           SEAT   5985                6
# 50392   350214314      Premium           Opel   8250                5
# 51125   357528924        Basic           SEAT  28490                7
# 53974   359772384        Basic          Skoda   5950                7
# 54721   360768625      Premium            BMW   2745                8
# 56967   360472733      Premium          Volvo   2990                5
# 62715   360793587        Basic        Renault   6450                8
# 63500   350214315        Basic         Nissan  13650                5
# 66323   354755822        Basic  Mercedes-Benz   6950                7
# ...

# %%
as24.loc[as24.duplicated(subset = ['article_id', 'make_name', 'price', 'first_zip_digit', 'created_date','first_registration_year', 'search_views'])]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 56967   360472733      Premium     Volvo   2990                5
#
#        first_registration_year created_date deleted_date  search_views  \
# 56967                     1998     12.10.18     08.01.19       43026.0
#
#        detail_views  stock_days          ctr
# 56967         597.0          88  0.013875331

# %%
as24.loc[as24.duplicated(subset = ['article_id', 'make_name', 'price', 'first_zip_digit', 'created_date','first_registration_year', 'search_views', 'ctr'])]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 56967   360472733      Premium     Volvo   2990                5
#
#        first_registration_year created_date deleted_date  search_views  \
# 56967                     1998     12.10.18     08.01.19       43026.0
#
#        detail_views  stock_days          ctr
# 56967         597.0          88  0.013875331

# %% [markdown]
# As we can see above from randomly choosing certain subsets of data. There are columns that share the same values with these duplicate article_id. Even our business metric in this case 'ctr' is same. Since 'ctr' is the ratio of 'detail_views' and 'search_views'.They may or maynot have the exact same number of search_views or detail_views. Let's add another subset 'stock_days'

# %%
as24.loc[as24.duplicated(subset = ['article_id', 'make_name', 'price', 'first_zip_digit', 'created_date','first_registration_year', 'stock_days'])]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %% [markdown]
# Let's check each of the duplicate article_id to get a better idea of what's going on here. Since there is only 16 of them

# %%
as24.loc[as24['article_id'] == 350214315]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 15997   350214315      Premium    Nissan  13650                5
# 63500   350214315        Basic    Nissan  13650                5
#
#        first_registration_year created_date deleted_date  search_views  \
# 15997                     2009     20.07.18     26.07.18         184.0
# 63500                     2009     20.07.18     01.08.18         368.0
#
#        detail_views  stock_days          ctr
# 15997           8.0           6  0.043478261
# 63500          16.0          12  0.043478261

# %% [markdown]
# We can see that the same article is listed under two different 'product_tier', 'Basic' and 'Premium' on the same 'created_date' but with different 'deleted_date'. Since there is a difference in deletion date, it can be assumed that this is not a error in the dataset, but something thats actually done by the customer (car dealer/seller) in this case. Notice the relation between these two listings. There seems to be a relation between 'search_views', 'detail_views' and 'stock_days'. All being two times more than that of 'Premium'. However resulting in the same 'ctr' for both listings.

# %%
as24.loc[as24['article_id'] == 354755822]
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 39922   354755822         Plus  Mercedes-Benz   6950                7
# 66323   354755822        Basic  Mercedes-Benz   6950                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 39922                     2005     20.08.18     18.10.18        2827.0
# 66323                     2005     20.08.18     20.10.18        5654.0
#
#        detail_views  stock_days          ctr
# 39922         202.0          59  0.071453838
# 66323         404.0          61  0.071453838

# %% [markdown]
# For this particular 'article_id' shown above we can again see two different 'product_tier', 'Basic' and 'Plus' again created with the same 'created_date'. This time we see a relation between 'search_views' and 'detail_views' but not with 'stock_days', being twice more than that of 'Plus'. 'ctr' values will be same as its a ratio of 'detail_views' and 'search_views'. Since we see the same 'ctr' values for comparison between Basic-Premium and Basic-Plus. This doesn't mean anything significant for 'ctr' and 'product_tier'. Let's do more analysis with our dataset.

# %%
as24.loc[as24['article_id'] == 360793587]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 41195   360793587      Premium   Renault   6450                8
# 62715   360793587        Basic   Renault   6450                8
#
#        first_registration_year created_date deleted_date  search_views  \
# 41195                     2015     16.10.18     08.01.19       69564.0
# 62715                     2015     16.10.18     10.01.19      139128.0
#
#        detail_views  stock_days          ctr
# 41195        1538.0          84  0.022109137
# 62715        3076.0          86   0.02100368

# %% [markdown]
# For this particular 'article_id' shown above we see a comparison between two different 'product_tier', 'Premium' and 'Basic'. Again with the same 'created_date' and 'search_views' and 'detail_views' being two times more in case of 'Basic' with difference of 2 in stock days. Also note there is an error in the 'ctr' value for the 'Basic' case. The value should be the same as the 'Premium' case, since 'ctr' is a ratio. But will come to 'ctr' correction further down below.

# %%
as24.loc[as24['article_id'] == 360768632]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 5323    360768632        Basic     Honda   1990                8
# 36742   360768632      Premium     Honda   1990                8
#
#        first_registration_year created_date deleted_date  search_views  \
# 5323                      2003     16.10.18     10.01.19       77132.0
# 36742                     2003     16.10.18     08.01.19       38566.0
#
#        detail_views  stock_days          ctr
# 5323         2552.0          86  0.033086138
# 36742        1276.0          84  0.033086138

# %%
as24.loc[as24['article_id'] == 360768627]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 23302   360768627        Basic   Renault   3250                8
# 75122   360768627      Premium   Renault   3250                8
#
#        first_registration_year created_date deleted_date  search_views  \
# 23302                     2008     16.10.18     10.01.19       72730.0
# 75122                     2008     16.10.18     08.01.19       36365.0
#
#        detail_views  stock_days          ctr
# 23302        1904.0          86  0.026179018
# 75122         952.0          84  0.026179018

# %%
as24.loc[as24['article_id'] == 350214314]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 39745   350214314        Basic      Opel   8250                5
# 50392   350214314      Premium      Opel   8250                5
#
#        first_registration_year created_date deleted_date  search_views  \
# 39745                     2012     20.07.18     01.08.18         134.0
# 50392                     2012     20.07.18     26.07.18          67.0
#
#        detail_views  stock_days          ctr
# 39745          10.0          12  0.074626866
# 50392           5.0           6  0.074626866

# %%
as24.loc[as24['article_id'] == 360768625]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 45945   360768625        Basic       BMW   2745                8
# 54721   360768625      Premium       BMW   2745                8
#
#        first_registration_year created_date deleted_date  search_views  \
# 45945                     2005     16.10.18     10.01.19      212854.0
# 54721                     2005     16.10.18     08.01.19      106427.0
#
#        detail_views  stock_days          ctr
# 45945        5798.0          86  0.027239328
# 54721        2899.0          84  0.027239328

# %%
as24.loc[as24['article_id'] == 357528924]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 2793    357528924      Premium      SEAT  28490                7
# 51125   357528924        Basic      SEAT  28490                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 2793                      2016     08.09.18     24.12.18       11756.0
# 51125                     2016     08.09.18     26.12.18       23512.0
#
#        detail_views  stock_days          ctr
# 2793          376.0         107  0.031983668
# 51125         752.0         109  0.031983668

# %%
as24.loc[as24['article_id'] == 360768624]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 5313    360768624        Basic   Hyundai   2990                8
# 37599   360768624      Premium   Hyundai   2990                8
#
#        first_registration_year created_date deleted_date  search_views  \
# 5313                      2007     16.10.18     10.01.19       37218.0
# 37599                     2007     16.10.18     08.01.19       18609.0
#
#        detail_views  stock_days        ctr
# 5313         1218.0          86  0.0327261
# 37599         609.0          84  0.0327261

# %%
as24.loc[as24['article_id'] == 360768628]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 14710   360768628      Premium   Renault   2495                8
# 69702   360768628        Basic   Renault   2495                8
#
#        first_registration_year created_date deleted_date  search_views  \
# 14710                     2006     16.10.18     08.01.19       23492.0
# 69702                     2006     16.10.18     10.01.19       46984.0
#
#        detail_views  stock_days          ctr
# 14710         570.0          84  0.024263579
# 69702        1140.0          86    0.0230504

# %%
as24.loc[as24['article_id'] == 364638423]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 22327   364638423        Basic      SEAT   5985                6
# 44079   364638423      Premium      SEAT   5985                6
#
#        first_registration_year created_date deleted_date  search_views  \
# 22327                     2010     28.11.18     08.02.19        9724.0
# 44079                     2010     28.11.18     07.02.19       19448.0
#
#        detail_views  stock_days         ctr
# 22327         313.0          72   0.0321884
# 44079         626.0          71  0.03057898

# %%
as24.loc[as24['article_id'] == 354755829]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 6451    354755829        Basic      Ford  10950                7
# 33971   354755829         Plus      Ford  10950                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 6451                      2009     20.08.18     20.10.18        5126.0
# 33971                     2009     20.08.18     18.10.18        2563.0
#
#        detail_views  stock_days        ctr
# 6451          242.0          61  0.0472103
# 33971         121.0          59  0.0472103

# %%
as24.loc[as24['article_id'] == 354755824]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 9440    354755824        Basic    Toyota  10950                7
# 70393   354755824         Plus    Toyota  10950                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 9440                      2010     20.08.18     20.10.18        4784.0
# 70393                     2010     20.08.18     18.10.18        2392.0
#
#        detail_views  stock_days          ctr
# 9440          222.0          61  0.046404682
# 70393         111.0          59  0.046404682

# %%
as24.loc[as24['article_id'] == 359772384]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 50575   359772384         Plus     Skoda   5950                7
# 53974   359772384        Basic     Skoda   5950                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 50575                     2011     04.10.18     18.10.18        2535.0
# 53974                     2011     04.10.18     20.10.18        5070.0
#
#        detail_views  stock_days          ctr
# 50575          79.0          14  0.029605523
# 53974         158.0          16  0.031163708

# %%
as24.loc[as24['article_id'] == 360472733]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 34016   360472733        Basic     Volvo   2990                5
# 56967   360472733      Premium     Volvo   2990                5
#
#        first_registration_year created_date deleted_date  search_views  \
# 34016                     1998     12.10.18     15.01.19       43026.0
# 56967                     1998     12.10.18     08.01.19       43026.0
#
#        detail_views  stock_days          ctr
# 34016         597.0          95  0.013875331
# 56967         597.0          88  0.013875331

# %%
as24.loc[as24['article_id'] == 358519054]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 15825   358519054         Plus     Volvo  14950                7
# 68339   358519054        Basic     Volvo  14950                7
#
#        first_registration_year created_date deleted_date  search_views  \
# 15825                     2008     20.09.18     18.10.18        3284.0
# 68339                     2008     20.09.18     20.10.18        6568.0
#
#        detail_views  stock_days         ctr
# 15825         106.0          28  0.03227771
# 68339         212.0          30  0.03227771

# %% [markdown]
# After observing all the duplicated 'article_id' in the dataset. We can conclude: (a) The same article can be listed under different 'product_tier', however we didn't find any article listed under all 3 tiers and there was no same article listed under both 'Premium' and 'Plus'.
# (b) The listings for the duplicates shared the same 'created_date'.
# (c) In all cases there was a relation between 'search_views' and 'detail_views' for both listed tiers, with 'Basic' having twice the values of that of 'Premium' and 'Plus' in respective cases.
# (d) In all cases Products listed under 'Basic' had more 'stock_days', but by a very small margin.
# (e) There are faulty 'ctr' values in some of our records.
#
# Let's clear our 'ctr' values with further inspection.

# %%
##checking for records with ctr value = 0, However this doesn't mean we will discard them immediately.
as24.loc[as24['ctr'] == '0']
# Out:
#        article_id product_tier   make_name  price  first_zip_digit  \
# 19      363908841        Basic     Renault  25900                7
# 32      363908703        Basic     Renault  14299                7
# 132     360767543        Basic        MINI   3195                2
# 140     363908512        Basic     Renault  29969                7
# 219     361162267        Basic      Jaguar  65950                4
# ...           ...          ...         ...    ...              ...
# 78161   355477561        Basic       Skoda  34950                7
# 78170   355461577        Basic        Fiat  12400                6
# 78262   354754940        Basic     Peugeot  10445                2
# 78299   360447563        Basic  Volkswagen  13900                8
# 78307   359753393        Basic       Skoda  14950                3
#
#        first_registration_year created_date deleted_date  search_views  \
# 19                        2018     20.11.18     12.12.18          92.0
# ...

# %% [markdown]
# We found out there are 1244 records with 'ctr' values being 0, 'ctr' value being 0 means there were 0 'detail_views' as of the ratio definition for that article. Lets check under what 'product_tier' do most of these records exist.

# %%
as24.loc[(as24['ctr'] == '0') & (as24['product_tier'] == 'Basic')]
# Out:
#        article_id product_tier   make_name  price  first_zip_digit  \
# 19      363908841        Basic     Renault  25900                7
# 32      363908703        Basic     Renault  14299                7
# 132     360767543        Basic        MINI   3195                2
# 140     363908512        Basic     Renault  29969                7
# 219     361162267        Basic      Jaguar  65950                4
# ...           ...          ...         ...    ...              ...
# 78161   355477561        Basic       Skoda  34950                7
# 78170   355461577        Basic        Fiat  12400                6
# 78262   354754940        Basic     Peugeot  10445                2
# 78299   360447563        Basic  Volkswagen  13900                8
# 78307   359753393        Basic       Skoda  14950                3
#
#        first_registration_year created_date deleted_date  search_views  \
# 19                        2018     20.11.18     12.12.18          92.0
# ...

# %% [markdown]
# All 1244 records with 'ctr' value being 0 share the same 'product_tier' being 'Basic'. That means there is no record with 'product_tier' being 'Premium' or 'Plus' with 0 'ctr' value i.e. also 0 'detail_views'. Lets quickly cross-check that.

# %%
as24.loc[(as24['ctr'] == '0') & (as24['product_tier'] == 'Premium') ]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %%
as24.loc[(as24['ctr'] == '0') & (as24['product_tier'] == 'Plus')]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %%
as24[['article_id', 'product_tier', 'ctr']]
# Out:
#        article_id product_tier          ctr
# 0       350625839        Basic    0.0378033
# 1       354412280        Basic  0.067925678
# 2       349572992        Basic  0.081613797
# 3       350266763        Basic  0.014008621
# 4       355688985        Basic  0.040816327
# ...           ...          ...          ...
# 78316   348704581        Basic  0.033357505
# 78317   359231940        Basic   0.01293617
# 78318   362425932        Basic     0.046875
# 78319   357164227        Basic  0.017934447
# 78320   353639932        Basic  0.034545455
#
# [78321 rows x 3 columns]

# %% [markdown]
# As of now, no records have been dropped. We are still working with 78321 records. Let's do further correction in our dataset.

# %%
##checking for errors in stock_days column.
as24.loc[(as24['stock_days'] < 0)]
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 161     359768765        Basic           MINI  19950                7
# 873     362809203        Basic         Toyota  13495                3
# 1269    347248705        Basic     Volkswagen  13925                7
# 5095    357831511        Basic        Bentley  69950                1
# 5477    348703289        Basic      Chevrolet  18900                7
# ...           ...          ...            ...    ...              ...
# 76209   362810854        Basic           Audi   4450                7
# 77128   364284041        Basic     Volkswagen   2950                1
# 77676   358519572        Basic  Mercedes-Benz  34950                7
# 77808   363557939        Basic         Nissan   6485                7
# 77954   361480979        Basic     Volkswagen   1950                7
#
#        first_registration_year created_date deleted_date  search_views  \
# ...

# %% [markdown]
# We found out that there are 93 articles with 'stock_days' being a negative value. 'stock_days' can never be negative as it's the difference between 'created_date' and 'deleted_date'. The minimum value it can take can be 0. Lets quickly correct that by removing all negative values from our dataset, as there is no column that should be having a negative value, however the value can be 0.

# %%
num = as24._get_numeric_data()

# %%
num[num<0] = 0

# %%
as24.loc[(as24['stock_days'] < 0)]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %% [markdown]
# Let's check if there's more errors in our main metric 'ctr'. By logic 'ctr' being a ratio should have a value between 0 & 1. If the 'detail_views' and 'search_views' are being generated from the same page, that is first article is being searched on the page and then clicked for a detailed view. There shouldn't be a way for 'detail_views' to be a higher number than 'search_views'. If the traffic for 'detail_views' includes other traffic sources, e.g. Social media, Paid ads, recommendations, other search engines, then it can be more than 'search_views' on the page.

# %%
as24.loc[(as24['ctr'] > '1')]
# Out:
#        article_id product_tier   make_name  price  first_zip_digit  \
# 849     361161145        Basic  Volkswagen  32450                6
# 1649    360100841        Basic        Opel   4949                8
# 3885    353638718        Basic  Volkswagen   3750                2
# 4169    357115804        Basic     Citroen   8940                2
# 4410    353090123        Basic        Fiat   4250                5
# ...           ...          ...         ...    ...              ...
# 71858   360491257        Basic         BMW   6999                7
# 73055   357159320        Basic        Fiat   3750                2
# 73402   364332664        Basic         Kia   7850                8
# 74868   361183805        Basic      Nissan   6950                2
# 76408   364317161        Basic      Toyota   1900                4
#
#        first_registration_year created_date deleted_date  search_views  \
# 849                       2018     20.10.18     08.11.18        2172.0
# ...

# %% [markdown]
# We found out there are 83 records with a higher value than 1. In the case of our first of the 83 records if you look at the actual 'ctr' being 27.624.309.392.265.100, our calculated 'ctr' is 60/2172 = 0.0276243093922652. We can easily weed out all the 'ctr' errors later by using our ratio formula.

# %%
as24.loc[(as24['article_id'] == 361161145)]
# Out:
#      article_id product_tier   make_name  price  first_zip_digit  \
# 849   361161145        Basic  Volkswagen  32450                6
#
#      first_registration_year created_date deleted_date  search_views  \
# 849                     2018     20.10.18     08.11.18        2172.0
#
#      detail_views  stock_days                     ctr
# 849          60.0          19  27.624.309.392.265.100

# %%
##checking for nullvalues in dataset
as24.isnull().sum().sum()
# Out:
# 44

# %%
as24['article_id'].isnull().values.any()
# Out:
# False

# %%
as24['product_tier'].isnull().values.any()
# Out:
# False

# %%
as24['make_name'].isnull().values.any()
# Out:
# False

# %%
as24['price'].isnull().values.any()
# Out:
# False

# %%
as24['search_views'].isnull().values.any()
# Out:
# True

# %%
as24['search_views'].isnull().sum()
# Out:
# 10

# %%
as24.loc[as24['search_views'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %%
np.where(pd.isnull(as24))
# Out:
# (array([ 6738, 10151, 10151, 10151, 19983, 21423, 21423, 21423, 26122,
#         27830, 27830, 27830, 28823, 38923, 43222, 47870, 47870, 47870,
#         52291, 57353, 57353, 57353, 60758, 60758, 60758, 63577, 63577,
#         63577, 65127, 65127, 65127, 66498, 66498, 66498, 68584, 69176,
#         70772, 71083, 71854, 72408, 72408, 72408, 72620, 78057],
#        dtype=int64),
#  array([11,  8,  9, 11, 11,  8,  9, 11, 11,  8,  9, 11, 11, 11, 11,  8,  9,
#         11, 11,  8,  9, 11,  8,  9, 11,  8,  9, 11,  8,  9, 11,  8,  9, 11,
#         11, 11, 11, 11, 11,  8,  9, 11, 11, 11], dtype=int64))

# %%
null_columns=as24.columns[as24.isnull().any()]
as24[null_columns].isnull().sum()
# Out:
# search_views    10
# detail_views    10
# ctr             24
# dtype: int64

# %% [markdown]
# We found out 44 null values in our dataset , 10 in 'search_views', 10 in 'detail_views' and 24 in 'ctr'. Also when 'detail_views' are null values, 'ctr' automatically will be nullvalue. Let's make the necessary corrections. We will drop 10 values where we have NaN values for 'search_views' and 'detail_views' (automatically NaN 'ctr' as well). However the 'ctr' values need to be updated as 0 where 'search_views' and 'detail_views' is 0.

# %%
print(as24[as24.isnull().any(axis=1)][null_columns]) 

##10searchviews are zero, 14searchviews are NaN
# Out:
#        search_views  detail_views  ctr
# 6738            0.0           0.0  NaN
# 10151           NaN           NaN  NaN
# 19983           0.0           0.0  NaN
# 21423           NaN           NaN  NaN
# 26122           0.0           0.0  NaN
# 27830           NaN           NaN  NaN
# 28823           0.0           0.0  NaN
# 38923           0.0           0.0  NaN
# 43222           0.0           0.0  NaN
# 47870           NaN           NaN  NaN
# 52291           0.0           0.0  NaN
# 57353           NaN           NaN  NaN
# 60758           NaN           NaN  NaN
# 63577           NaN           NaN  NaN
# 65127           NaN           NaN  NaN
# 66498           NaN           NaN  NaN
# 68584           0.0           0.0  NaN
# 69176           0.0           0.0  NaN
# 70772           0.0           0.0  NaN
# 71083           0.0           0.0  NaN
# 71854           0.0           0.0  NaN
# 72408           NaN           NaN  NaN
# 72620           0.0           0.0  NaN
# ...

# %%
as24 = as24[as24['search_views'].notna()]

## not drop rows where search_views doesn't have a value
## only using rows where search_views have a value

# %%
as24
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 0       350625839        Basic     Mitsubishi  16750                5
# 1       354412280        Basic  Mercedes-Benz  35950                4
# 2       349572992        Basic  Mercedes-Benz  11950                3
# 3       350266763        Basic           Ford   1750                6
# 4       355688985        Basic  Mercedes-Benz  26500                3
# ...           ...          ...            ...    ...              ...
# 78316   348704581        Basic          Lexus  15740                8
# 78317   359231940        Basic        Hyundai   2950                6
# 78318   362425932        Basic     Volkswagen   7850                8
# 78319   357164227        Basic         Toyota  13945                5
# 78320   353639932        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# ...

# %% [markdown]
# Now we only have 78311 records as 10 NaN values have been dropped. It's not always best-advised to drop NaN values, but since its only 10 records with respect to 78321. I decided to drop them.

# %%
as24.loc[(as24['ctr'] > '1')]
# Out:
#        article_id product_tier   make_name  price  first_zip_digit  \
# 849     361161145        Basic  Volkswagen  32450                6
# 1649    360100841        Basic        Opel   4949                8
# 3885    353638718        Basic  Volkswagen   3750                2
# 4169    357115804        Basic     Citroen   8940                2
# 4410    353090123        Basic        Fiat   4250                5
# ...           ...          ...         ...    ...              ...
# 71858   360491257        Basic         BMW   6999                7
# 73055   357159320        Basic        Fiat   3750                2
# 73402   364332664        Basic         Kia   7850                8
# 74868   361183805        Basic      Nissan   6950                2
# 76408   364317161        Basic      Toyota   1900                4
#
#        first_registration_year created_date deleted_date  search_views  \
# 849                       2018     20.10.18     08.11.18        2172.0
# ...

# %%
as24['ctr'] = as24['detail_views']/as24['search_views']
# Out:
# <ipython-input-59-2694574f8407>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   as24['ctr'] = as24['detail_views']/as24['search_views']

# %% [markdown]
# All corrections to 'ctr' values was made by our ratio formula as given in the description of the dataset. However, if 'detail_views' are higher than 'search_views', our correction will be false. Lets quickly check if there's any records with more 'detail_views' than 'search_views'.

# %%
as24
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 0       350625839        Basic     Mitsubishi  16750                5
# 1       354412280        Basic  Mercedes-Benz  35950                4
# 2       349572992        Basic  Mercedes-Benz  11950                3
# 3       350266763        Basic           Ford   1750                6
# 4       355688985        Basic  Mercedes-Benz  26500                3
# ...           ...          ...            ...    ...              ...
# 78316   348704581        Basic          Lexus  15740                8
# 78317   359231940        Basic        Hyundai   2950                6
# 78318   362425932        Basic     Volkswagen   7850                8
# 78319   357164227        Basic         Toyota  13945                5
# 78320   353639932        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# ...

# %%
as24.loc[(as24['detail_views'] > as24['search_views'])]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 32000   355652116        Basic      Fiat   6650                7
# 39172   351144455        Basic    Nissan  16970                1
#
#        first_registration_year created_date deleted_date  search_views  \
# 32000                     2008     28.08.18     28.08.18          12.0
# 39172                     2013     28.07.18     28.07.18          15.0
#
#        detail_views  stock_days       ctr
# 32000          22.0           0  1.833333
# 39172          21.0           0  1.400000

# %%
as24.loc[(as24['ctr'] > 1)]
# Out:
#        article_id product_tier make_name  price  first_zip_digit  \
# 32000   355652116        Basic      Fiat   6650                7
# 39172   351144455        Basic    Nissan  16970                1
#
#        first_registration_year created_date deleted_date  search_views  \
# 32000                     2008     28.08.18     28.08.18          12.0
# 39172                     2013     28.07.18     28.07.18          15.0
#
#        detail_views  stock_days       ctr
# 32000          22.0           0  1.833333
# 39172          21.0           0  1.400000

# %% [markdown]
# We found out 2 records with higher 'detail_views' than 'search_views'. Lets drop them and do a cross check.

# %%
##dropping using index
as24 = as24.drop([32000, 39172])

# %%
as24.loc[(as24['ctr'] > 1)]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %%
as24.loc[(as24['detail_views'] > as24['search_views'])]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %%
as24
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 0       350625839        Basic     Mitsubishi  16750                5
# 1       354412280        Basic  Mercedes-Benz  35950                4
# 2       349572992        Basic  Mercedes-Benz  11950                3
# 3       350266763        Basic           Ford   1750                6
# 4       355688985        Basic  Mercedes-Benz  26500                3
# ...           ...          ...            ...    ...              ...
# 78316   348704581        Basic          Lexus  15740                8
# 78317   359231940        Basic        Hyundai   2950                6
# 78318   362425932        Basic     Volkswagen   7850                8
# 78319   357164227        Basic         Toyota  13945                5
# 78320   353639932        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# ...

# %% [markdown]
# Now we are left with 78309 records, we still have to update our 'ctr' values as 0 for values where 'detail_views' are 0. Since we used the ratio formula already above and we already know the number of records for which we need to make corrections on 'ctr' values. It can be done easily in the following way.

# %%
as24['ctr'].isnull().values.any()
# Out:
# True

# %%
as24['ctr'].isnull().sum()
# Out:
# 14

# %%
as24.loc[(as24['ctr'] == '')]
# Out:
# Empty DataFrame
# Columns: [article_id, product_tier, make_name, price, first_zip_digit, first_registration_year, created_date, deleted_date, search_views, detail_views, stock_days, ctr]
# Index: []

# %%
as24['ctr'] = as24['ctr'].fillna(0)

# %%
as24['ctr'].isnull().sum()
# Out:
# 0

# %% [markdown]
# As of now we have 78309 records and all the corrections as of the above analysis are made. I will quickly export the corrected dataframe as csv.

# %%
as24.to_csv('as24.csv', index=False)

# %%
as24
# Out:
#        article_id product_tier      make_name  price  first_zip_digit  \
# 0       350625839        Basic     Mitsubishi  16750                5
# 1       354412280        Basic  Mercedes-Benz  35950                4
# 2       349572992        Basic  Mercedes-Benz  11950                3
# 3       350266763        Basic           Ford   1750                6
# 4       355688985        Basic  Mercedes-Benz  26500                3
# ...           ...          ...            ...    ...              ...
# 78316   348704581        Basic          Lexus  15740                8
# 78317   359231940        Basic        Hyundai   2950                6
# 78318   362425932        Basic     Volkswagen   7850                8
# 78319   357164227        Basic         Toyota  13945                5
# 78320   353639932        Basic     Volkswagen  38800                7
#
#        first_registration_year created_date deleted_date  search_views  \
# ...

# %% [markdown]
# A/B tests and answering questions. Now that we have cleared all flaws in our dataset, let's quickly check what all columns have a correlation between them and how significant they are. It's clear from the question that 'ctr' is our dependent metric, depending on other independent metric. We can easily check relations between continous data using a correlation matrix (Pearson Correlation). I will be using sklearn module for the split and plotting the matrix.

# %%
#Feature Matrix
X = as24[['price', 'search_views', 'detail_views', 'stock_days']]
y = as24["ctr"]

# %%
as24.head(10)
# Out:
#    article_id product_tier      make_name  price  first_zip_digit  \
# 0   350625839        Basic     Mitsubishi  16750                5
# 1   354412280        Basic  Mercedes-Benz  35950                4
# 2   349572992        Basic  Mercedes-Benz  11950                3
# 3   350266763        Basic           Ford   1750                6
# 4   355688985        Basic  Mercedes-Benz  26500                3
# 5   361204569        Basic     Volkswagen  24890                6
# 6   362784907        Basic           Fiat   2850                7
# 7   363942101        Basic        Renault  23740                2
# 8   358875204        Basic        Renault   7850                6
# 9   357547566        Basic          Mazda  13950                3
#
#    first_registration_year created_date deleted_date  search_views  \
# 0                     2013     24.07.18     24.08.18        3091.0
# 1                     2015     16.08.18     07.10.18        3283.0
# ...

# %%
X.head(10)
# Out:
#    price  search_views  detail_views  stock_days
# 0  16750        3091.0         123.0          30
# 1  35950        3283.0         223.0          52
# 2  11950        3247.0         265.0          51
# 3   1750        1856.0          26.0         101
# 4  26500         490.0          20.0          12
# 5  24890         125.0           6.0           2
# 6   2850         172.0           4.0           1
# 7  23740        1499.0          99.0          87
# 8   7850        4329.0         133.0          75
# 9  13950        2257.0          89.0          32

# %%
y.head(10)
# Out:
# 0    0.039793
# 1    0.067926
# 2    0.081614
# 3    0.014009
# 4    0.040816
# 5    0.048000
# 6    0.023256
# 7    0.066044
# 8    0.030723
# 9    0.039433
# Name: ctr, dtype: float64

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((54816, 4), (23493, 4))

# %%
X_train.corr()
# Out:
#                  price  search_views  detail_views  stock_days
# price         1.000000      0.005777      0.032535    0.089925
# search_views  0.005777      1.000000      0.820781    0.267068
# detail_views  0.032535      0.820781      1.000000    0.284241
# stock_days    0.089925      0.267068      0.284241    1.000000

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(15,12))
plt.title('Correlation Matrix')
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.flag)
plt.show()

# %% [markdown]
# Correlation is a measure to see how closely two or more variables are related. This is done by a correlation coefficient, which tells how strong is the relationship between two variables. Correlation coefficient takes a value between -1 to 1, with 1 being a strong positive relationship, -1 being a strong negative relationship and 0 meaning there is no relationship at all. As we can observe from the plot with all our continous variables, there is a strong positive relationship (82%) between 'detail_views' and 'search_views' which means, if our 'search_views' go up our 'detail_views' also go up. There is no strong negative relationship between our variables. However, there is almost no relationship between 'search_views' and 'price', same as that for 'detail_views' and 'price'. Let's see out of all these continous variables which variables has a strong correlation with other variables. Any guesses?
#
# I will be writing a function to select highly correlated feature keeping the threshold at 0.7(70%). However if this threshold is changed immensely, we might see other highly correlated feature as output.

# %%
# with the following function we can select highly correlated features

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 1

# %%
corr_features
# Out:
# {'detail_views'}

# %% [markdown]
# Not that hard to guess after looking at the correlation matrix. 'detail_views' is the most related metric with other continous variables in the dataset. Let's not forget this is actually not a significant result as we have not yet added 'ctr' as a metric in this matrix and also are not yet comparing our metric 'ctr' with 'product_tier'. We will come there in few more steps as 'product_tier' is a categorical metric. Let's have some more graphs for our correlation matrix.

# %%
##heatmap
import seaborn as sns
#Using Pearson Correlation
corrmat = X_train.corr()
fig, ax = plt.subplots()
fig.set_size_inches(15,12)
ax.set_title('Heatmap')
sns.heatmap(corrmat)
# Out:
# <AxesSubplot:title={'center':'Heatmap'}>

# %%
g = sns.pairplot(cor)
g.fig.suptitle("Pairplot of continous variables", y=1.08)
# Out:
# Text(0.5, 1.08, 'Pairplot of continous variables')

# %% [markdown]
# Let's add 'ctr' in our matrix and see how correlated it is with other continous metrics. It's pretty easy to say right away, that 'ctr' should have a negative correlation with 'search_views' and a positive correlation with 'detail_views', Or we could be wrong?

# %%
X1 = as24[['price', 'search_views', 'detail_views', 'stock_days', 'ctr']]
y1 = as24["product_tier"]

# %%
X1.head(10)
# Out:
#    price  search_views  detail_views  stock_days       ctr
# 0  16750        3091.0         123.0          30  0.039793
# 1  35950        3283.0         223.0          52  0.067926
# 2  11950        3247.0         265.0          51  0.081614
# 3   1750        1856.0          26.0         101  0.014009
# 4  26500         490.0          20.0          12  0.040816
# 5  24890         125.0           6.0           2  0.048000
# 6   2850         172.0           4.0           1  0.023256
# 7  23740        1499.0          99.0          87  0.066044
# 8   7850        4329.0         133.0          75  0.030723
# 9  13950        2257.0          89.0          32  0.039433

# %%
y1.head(10)
# Out:
# 0    Basic
# 1    Basic
# 2    Basic
# 3    Basic
# 4    Basic
# 5    Basic
# 6    Basic
# 7    Basic
# 8    Basic
# 9    Basic
# Name: product_tier, dtype: object

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(
    X1,
    y1,
    test_size=0.3,
    random_state=0)

X1_train.shape, X1_test.shape
# Out:
# ((54816, 5), (23493, 5))

# %%
X1_train.corr()
# Out:
#                  price  search_views  detail_views  stock_days       ctr
# price         1.000000      0.005777      0.032535    0.089925  0.005957
# search_views  0.005777      1.000000      0.820781    0.267068 -0.056678
# detail_views  0.032535      0.820781      1.000000    0.284241  0.112930
# stock_days    0.089925      0.267068      0.284241    1.000000 -0.147584
# ctr           0.005957     -0.056678      0.112930   -0.147584  1.000000

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(15,12))
cor = X1_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.flag)
plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# As expected, we have a positive correlation between 'ctr' and 'detail_views' and a negative correlation between 'ctr' and 'search_views'. However the correlations are not that strong. 'ctr' DOESN'T SHOW ANY CORRELATION WITH OTHER ""CONTINOUS"" VARIABLES. We can now surely say that 'detail_views' is the most correlated metric in our dataset. Let's do a quick crosscheck

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X1_train, 0.7)
len(set(corr_features))
# Out:
# 1

# %%
corr_features
# Out:
# {'detail_views'}

# %% [markdown]
# Now let's add our main comparison categorical metric 'product_tier'. Before we do that I will add a pairplot of the whole dataset to get a rough analysis of distribution of data around 'product_tier'.

# %%
#sns.pairplot(as24, hue='product_tier')
h = sns.pairplot(as24, hue= 'product_tier')
h.fig.suptitle("Pairplot of entire dataset", y=1.08)
#plt.savefig(r'C:\Users\kumar\OneDrive\Desktop\impact.png')
# Out:
# Text(0.5, 1.08, 'Pairplot of entire dataset')

# %%
as24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78309 entries, 0 to 78320
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   article_id               78309 non-null  int64
#  1   product_tier             78309 non-null  object
#  2   make_name                78309 non-null  object
#  3   price                    78309 non-null  int64
#  4   first_zip_digit          78309 non-null  int64
#  5   first_registration_year  78309 non-null  int64
#  6   created_date             78309 non-null  object
#  7   deleted_date             78309 non-null  object
#  8   search_views             78309 non-null  float64
#  9   detail_views             78309 non-null  float64
#  10  stock_days               78309 non-null  int64
#  11  ctr                      78309 non-null  float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 7.8+ MB

# %% [markdown]
# A small description to make readers understand some statistical concepts related to this case analysis. Our goal in this analysis is to find out a correlation between 'ctr' and 'product_tier'. What is the cause of this correlation? We already know if a 'product_tier' is 'Premium', it has a higher preference listing followed by 'Plus'. Now our goal is to find how the strength of association can be measured. Previously we observed this strength amongst continous variables in the dataset using a correlation matrix. There are different tests for different scenarios. Some of them will be defined in short below:
#
# (a) Chi-squared: Used for comparison between variables that are only categorical.
# (b) Correlation: Used for measuring relationship between variables that are only continous.
# (c) T-test: Used for comparison between categorical and continous variables.
#
# It's easy to decide in our case we have to use T-test. But since we have more than one categorical variable (3 tiers) we will be using a special type of T-test called as Anova. This helps us to find if there is a significant difference between these groups and how significant is the difference.
#
# Some other more general concepts in short that readers might find helpful:
#
# Null Hypothesis: There is no difference between the two or more variants. They all perform equally.
# Alternate Hypothesis: There is a difference between the two or more variants.
#
# When to accept or reject null hypothesis? This is done by using p-value denoted normally as α (alpha), also known as significance value. If p-value ≤ 0.05, we reject Null hypothesis. This will tell if there is a significant difference in the variants. Let's proceed with our Anova test. I will be using scipy library to calculate p-value.

# %%
#anova test(f-test)

a_test = as24[['product_tier', 'ctr']]

# %%
a_test.head(10)
# Out:
#   product_tier       ctr
# 0        Basic  0.039793
# 1        Basic  0.067926
# 2        Basic  0.081614
# 3        Basic  0.014009
# 4        Basic  0.040816
# 5        Basic  0.048000
# 6        Basic  0.023256
# 7        Basic  0.066044
# 8        Basic  0.030723
# 9        Basic  0.039433

# %%
grps= pd.unique(a_test.product_tier.values)

# %%
grps
# Out:
# array(['Basic', 'Premium', 'Plus'], dtype=object)

# %%
atest_data = {grp:a_test['ctr'][a_test.product_tier == grp] for grp in grps}

# %%
atest_data
# Out:
# {'Basic': 0        0.039793
#  1        0.067926
#  2        0.081614
#  3        0.014009
#  4        0.040816
#             ...
#  78316    0.033358
#  78317    0.013617
#  78318    0.046875
#  78319    0.017934
#  78320    0.036364
#  Name: ctr, Length: 75409, dtype: float64,
#  'Premium': 38       0.013324
#  51       0.018905
#  57       0.019608
#  69       0.032495
#  70       0.019113
#             ...
#  78160    0.041018
#  78184    0.101239
#  78213    0.036918
#  78291    0.066986
#  78295    0.046128
#  Name: ctr, Length: 2324, dtype: float64,
#  'Plus': 81       0.035566
#  158      0.011792
#  170      0.033398
#  198      0.024949
#  213      0.033988
#             ...
#  77490    0.027094
#  77508    0.024364
#  77980    0.088221
#  78093    0.063851
#  78267    0.043546
#  Name: ctr, Length: 576, dtype: float64}

# %%
import scipy.stats as stats

# %%
F, p = stats.f_oneway(atest_data['Basic'], atest_data['Premium'], atest_data['Plus'])

# %% [markdown]
# You may question what is F and p here? p is p-value defined earlier above and F is the ratio of the variance of group means and means of within group differences. In our cases groups are the tiers.

# %%
print(p)
# Out:
# 2.4042182854423958e-48

# %%
if p<0.05:
    print("reject null hypothesis") ##Rejecting null hypothesis means there is a statistical significant difference
else:
    print("accept null hypothesis") ##Accepting null hypothesis means there is a statistical significant difference
# Out:
# reject null hypothesis

# %%
print(F)
# Out:
# 109.80053452218384

# %% [markdown]
# So now that we know there is a statistical significant difference between the tiers. Our goal should be to measure how significant these differences are. This can be done by different methods, in our case we will be using Post-hoc test. A Post-hoc test is perfomed when we know that we are rejecting the null hypothesis (anova is significant) and there are three or more group variants. Post-hoc tests are of different types, e.g. Bonferroni method, Tukey HSD (Honestly significant difference), Games-Howell.
#
# When to use which type?
# Usually the most safest option considered is to use Bonferroni method. However no test is perfect, Bonferroni being a very conservative method often increases the Type-2 error ( We miss a significant that is truly there, i.e., less precision).
# For unequal sample sizes, better methods like Gabriel's (small sample) and Hochberg's GT2 (large sample) are used.
# For unequal variances, we use Games-Howell method. There are many other methods that exist, I have just mentioned few of them as examples here.
#
# Dont worry! we will be using more than one type just to compare. If our result is True with one method it should most likely be True with other method as well, However there might be a slight difference in significance values.
#
# Let's first quickly check if our product tiers have unequal variances. It's not that hard to answer that they do have unequal variances, but lets perform a test to be sure. This can be done using Levene F-test. If p-value is less than 0.05 (significant), we can say the variances are not equal.

# %%
##Posthoc test

##levene test to check if the product tiers have equal variances

myproduct = as24['product_tier']
myctr = as24['ctr']

# %%
##Boolean creation
mytier1 = myproduct == 'Basic'
mytier2 = myproduct == 'Plus'
mytier3 = myproduct == 'Premium'

# %%
##creating list using boolean

mytier1score = myctr[mytier1].dropna()
mytier2score = myctr[mytier2].dropna()
mytier3score = myctr[mytier3].dropna()

# %%
from scipy.stats import levene

# %%
levene(mytier1score, mytier2score, mytier3score, center='mean')
# Out:
# LeveneResult(statistic=187.11448251673792, pvalue=8.526604434139225e-82)

# %% [markdown]
# Since the value of p is really less than 0.05 we can say the variances are not equal. When the variances are not equal we can use Games-Howell method as a type of Posthoc test. However Games-Howell is sometimes imprecise, pairwise comparison test. But we will be checking with all the other methods as well. Let's proceed.

# %%
import pingouin as pg
from pingouin import pairwise_ttests

# %%
##arguments in pairwise_ttests 
##dv = dependent variable in our case 'ctr'
##between = independent variable in our case 'product_tier'
##data = name of the dataframe
##padjust = the adjustment method which takes the following options : 'none', 'bonf', 
##'sidak', 'holm', 'fdr_bh' and 'fdr_by'. none means no correction, 'bonf' means bonferroni type of posthoc, 'fdr_bh' means Benjamini/Hochberg..etc
##But as we have unequal variances we will be using the Games-Howell. However we can try all of them.

##Games-Howell method uses a function 'pairwise_gameshowell' for padjust

# %% [markdown]
# Bonferroni is considered the safest option amongst all Post hoc tests.

# %%
posthocs= pairwise_ttests(dv= 'ctr', between= 'product_tier', padjust = 'bonf', data= as24, correction = False)
posthocs
# Out:
#        Contrast      A        B  Paired  Parametric          T      dof  \
# 0  product_tier  Basic     Plus   False        True   3.894227  75983.0
# 1  product_tier  Basic  Premium   False        True  14.308017  77731.0
# 2  product_tier   Plus  Premium   False        True   5.032451   2898.0
#
#         Tail         p-unc        p-corr p-adjust       BF10    hedges
# 0  two-sided  9.859675e-05  2.957902e-04     bonf     87.722  0.162876
# 1  two-sided  2.233724e-46  6.701171e-46     bonf  5.009e+42  0.301334
# 2  two-sided  5.138293e-07  1.541488e-06     bonf  1.417e+04  0.234173

# %% [markdown]
# We can see p-corr as our p-value being the most significant between the variants: 'Basic' and 'Premium' followed by a very much smaller significant difference between the variants: 'Plus' and 'Premium' and even smaller significant difference between the variants: 'Basic' and 'Plus'. Note that the smaller the p-value, the bigger is the difference between the variants. The smallest p-value by a huge margin is noticed between the variants: 'Basic' and 'Premium', followed by 'Plus' and 'Premium' and least difference being between the variants: 'Basic' and 'Plus'. Let's plot this result and check if other methods give us the same result!

# %%
import statsmodels.api as sa
import scikit_posthocs as sp
sp.posthoc_conover(as24, val_col= 'ctr', group_col ='product_tier')
pc = sp.posthoc_conover(as24, val_col= 'ctr', group_col ='product_tier')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.90, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
##plt.savefig(r'C:\Users\kumar\OneDrive\Desktop\impact.png', dpi=1000)
# Out:
# (<AxesSubplot:>, <matplotlib.colorbar.ColorbarBase at 0x23c98a2b430>)

# %% [markdown]
# Plotting a heatmap

# %%
pc = sp.posthoc_conover(as24, val_col='ctr', group_col='product_tier')
# Format: diagonal, non-significant, p<0.001, p<0.01, p<0.05
cmap = ['1', '#fb6a4a',  '#08306b',  '#4292c6', '#c6dbef']
heatmap_args = {'cmap': cmap, 'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.90, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot:>, <matplotlib.colorbar.ColorbarBase at 0x23c98ac0f10>)

# %%
posthocs = pairwise_ttests(dv= 'ctr', between= 'product_tier', padjust = 'sidak', data= as24, correction = False)
posthocs
# Out:
#        Contrast      A        B  Paired  Parametric          T      dof  \
# 0  product_tier  Basic     Plus   False        True   3.894227  75983.0
# 1  product_tier  Basic  Premium   False        True  14.308017  77731.0
# 2  product_tier   Plus  Premium   False        True   5.032451   2898.0
#
#         Tail         p-unc    p-corr p-adjust       BF10    hedges
# 0  two-sided  9.859675e-05  0.000296    sidak     87.722  0.162876
# 1  two-sided  2.233724e-46  0.000000    sidak  5.009e+42  0.301334
# 2  two-sided  5.138293e-07  0.000002    sidak  1.417e+04  0.234173

# %% [markdown]
# We observe similar test results even with a different method. There is a huge impact on 'ctr' due to a 'Premium' listing. However there isn't much of an impact on 'ctr' as a 'Plus' listing when compared with 'Premium' or 'Basic' listing.

# %%
import statsmodels.api as sa
import scikit_posthocs as sp
sp.posthoc_conover(as24, val_col= 'ctr', group_col ='product_tier')
pc = sp.posthoc_conover(as24, val_col= 'ctr', group_col ='product_tier', p_adjust= 'sidak')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.90, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot:>, <matplotlib.colorbar.ColorbarBase at 0x23c98b5cfd0>)

# %%
pc = sp.posthoc_conover(as24, val_col='ctr', group_col='product_tier', p_adjust = 'sidak')
# Format: diagonal, non-significant, p<0.001, p<0.01, p<0.05
cmap = ['1', '#fb6a4a',  '#08306b',  '#4292c6', '#c6dbef']
heatmap_args = {'cmap': cmap, 'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.90, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot:>, <matplotlib.colorbar.ColorbarBase at 0x23c9bb2b280>)

# %% [markdown]
# You might think this is a copied graph from our previous Bornferroni method. Yes and no!
# No! because if you notice the code for this graph when using the pc = sp.posthoc_conover, another argument of p_adjust = 'sidak' has been added.
# Yes! because we notice the same results and the graph looks the same.

# %%
posthocs = pairwise_ttests(dv= 'ctr', between= 'product_tier', padjust = 'fdr_bh', data= as24, correction = False)
posthocs
# Out:
#        Contrast      A        B  Paired  Parametric          T      dof  \
# 0  product_tier  Basic     Plus   False        True   3.894227  75983.0
# 1  product_tier  Basic  Premium   False        True  14.308017  77731.0
# 2  product_tier   Plus  Premium   False        True   5.032451   2898.0
#
#         Tail         p-unc        p-corr p-adjust       BF10    hedges
# 0  two-sided  9.859675e-05  9.859675e-05   fdr_bh     87.722  0.162876
# 1  two-sided  2.233724e-46  6.701171e-46   fdr_bh  5.009e+42  0.301334
# 2  two-sided  5.138293e-07  7.707440e-07   fdr_bh  1.417e+04  0.234173

# %%
import statsmodels.api as sa
import scikit_posthocs as sp
sp.posthoc_conover(as24, val_col= 'ctr', group_col ='product_tier')
pc = sp.posthoc_conover(as24, val_col= 'ctr', group_col ='product_tier', p_adjust= 'fdr_bh')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.90, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot:>, <matplotlib.colorbar.ColorbarBase at 0x23c9bbc0340>)

# %%
pc = sp.posthoc_conover(as24, val_col='ctr', group_col='product_tier', p_adjust = 'fdr_bh')
# Format: diagonal, non-significant, p<0.001, p<0.01, p<0.05
cmap = ['1', '#fb6a4a',  '#08306b',  '#4292c6', '#c6dbef']
heatmap_args = {'cmap': cmap, 'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.90, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
# Out:
# (<AxesSubplot:>, <matplotlib.colorbar.ColorbarBase at 0x23c9cf24580>)

# %% [markdown]
# We notice the same results!! Along with this python code, I will be attaching a small ppt. to answer in words some of the questions asked in this case. I am grateful towards you for giving me this opportunity to work on this case.
